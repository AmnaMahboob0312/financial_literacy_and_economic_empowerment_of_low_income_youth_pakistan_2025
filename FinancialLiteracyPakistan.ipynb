# %% [markdown]
# # **Study topic: Financial Literacy & economic empowerment of low income youth (university students edition)**
#
# *By Amna Mahboob, Amina Falak & Awaiz Saim *
#
#
# Research questions:
#
# which factors improve financial literacy amoung university students?
#
# which factors improve empowerment amoung university students?

# %% [markdown]
# Data collection:
#
# -surveys carried out in google form
#
#
#
# Data restrictions of participants:
#
# -University students
#
# -age between 20 to 25
#
# -students within islamabad,Pakistan

# %% [markdown]
# **the original csv file had more

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/fin eco cleaned dataset.csv')
df.columns
# Out:
# Index(['Respondant ID', 'Age', 'Gender', 'Hostellite', 'City',
#        'University Name', 'Employment Status', 'Financial Training',
#        'Family Income (Monthly)', 'Parents' Education',
#        'Access to Financial Services', 'Has Bank Account', 'ECOQ1', 'ECOQ2',
#        'ECOQ3', 'ECOQ4', 'ECOQ5', 'FINQ1', 'FINQ2', 'FINQ3', 'FINQ4', 'FINQ5',
#        'FINQ6', 'FINQ7', 'FINQ8 '],
#       dtype='object')

# %%
df.isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondant ID                 84 non-null     int64
#  1   Age                           84 non-null     int64
#  2   Gender                        84 non-null     object
#  3   Hostellite                    84 non-null     object
#  4   City                          69 non-null     object
#  5   University Name               84 non-null     object
#  6   Employment Status             83 non-null     object
#  7   Financial Training            83 non-null     object
#  8   Family Income (Monthly)       84 non-null     object
#  9   Parents' Education            84 non-null     object
#  10  Access to Financial Services  82 non-null     object
#  11  Has Bank Account              84 non-null     object
# ...

# %%
import matplotlib.pyplot as plt

null_counts = df.isnull().sum()

null_counts = null_counts[null_counts > 0]


plt.figure(figsize=(10, 6))
null_counts.plot(kind='bar', color='coral')
plt.title('Null Values per Column', fontsize=16, fontweight='bold')
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Number of Null Values', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', alpha=0.3)
plt.show()

# Print summary
print(f"Total null values: {null_counts.sum()}")
print(f"Columns with nulls: {len(null_counts)}")
# Out:
# Total null values: 20
# Columns with nulls: 5

# %%
columns = ['City', 'Employment Status', 'Financial Training', 'Access to Financial Services','FINQ6']

for col in columns:
    mode_val = df[col].mode()[0]
    print(f"Mode of {col}: {mode_val}")
# Out:
# Mode of City: Other
# Mode of Employment Status: Student
# Mode of Financial Training: No
# Mode of Access to Financial Services: Yes
# Mode of FINQ6: Debit uses your own money; credit is borrowed money

# %%
df['City'].fillna(df['City'].mode()[0], inplace=True)
df['Employment Status'].fillna(df['Employment Status'].mode()[0], inplace=True)
df['Financial Training'].fillna(df['Financial Training'].mode()[0], inplace=True)
df['Access to Financial Services'].fillna(df['Access to Financial Services'].mode()[0], inplace=True)
df['FINQ6'].fillna(df['FINQ6'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-4268153430.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['City'].fillna(df['City'].mode()[0], inplace=True)
# /tmp/ipython-input-4268153430.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Respondant ID                   0
# Age                             0
# Gender                          0
# Hostellite                      0
# City                            0
# University Name                 0
# Employment Status               0
# Financial Training              0
# Family Income (Monthly)         0
# Parents' Education              0
# Access to Financial Services    0
# Has Bank Account                0
# ECOQ1                           0
# ECOQ2                           0
# ECOQ3                           0
# ECOQ4                           0
# ECOQ5                           0
# FINQ1                           0
# FINQ2                           0
# FINQ3                           0
# FINQ4                           0
# FINQ5                           0
# FINQ6                           0
# FINQ7                           0
# FINQ8                           0
# dtype: int64

# %%
df.duplicated().sum()

df.drop_duplicates()
print("number of rows left: ")
len(df)
# Out:
# number of rows left:
# 84

# %%
ecoq1_map = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Neutral': 3,
    'Agree': 4,
    'Strongly Agree': 5
}

df['ECOQ1_encoded'] = df['ECOQ1'].map(ecoq1_map)
print(df[['ECOQ1', 'ECOQ1_encoded']])

ecoq2_map = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Neutral': 3,
    'Agree': 4,
    'Strongly Agree': 5
}

df['ECOQ2_encoded'] = df['ECOQ2'].map(ecoq2_map)
print(df[['ECOQ2', 'ECOQ2_encoded']])

ecoq3_map = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Neutral': 3,
    'Agree': 4,
    'Strongly Agree': 5
}

df['ECOQ3_encoded'] = df['ECOQ3'].map(ecoq3_map)
print(df[['ECOQ3', 'ECOQ3_encoded']])

ecoq4_map = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Neutral': 3,
    'Agree': 4,
    'Strongly Agree': 5
}

df['ECOQ4_encoded'] = df['ECOQ4'].map(ecoq4_map)
print(df[['ECOQ4', 'ECOQ4_encoded']])

ecoq5_map = {
    'Strongly disagree': 1,
    'Disagree': 2,
    'Neutral': 3,
    'Agree': 4,
    'Strongly Agree': 5
}

df['ECOQ5_encoded'] = df['ECOQ5'].map(ecoq5_map)
print(df[['ECOQ5', 'ECOQ5_encoded']])
# Out:
#              ECOQ1  ECOQ1_encoded
# 0            Agree              4
# 1         Disagree              2
# 2            Agree              4
# 3            Agree              4
# 4          Neutral              3
# ..             ...            ...
# 79         Neutral              3
# 80  Strongly Agree              5
# 81           Agree              4
# 82           Agree              4
# 83  Strongly Agree              5
#
# [84 rows x 2 columns]
#                 ECOQ2  ECOQ2_encoded
# 0               Agree              4
# 1            Disagree              2
# 2             Neutral              3
# 3   Strongly disagree              1
# 4            Disagree              2
# ..                ...            ...
# 79  Strongly disagree              1
# 80           Disagree              2
# 81           Disagree              2
# 82  Strongly disagree              1
# 83     Strongly Agree              5
#
# [84 rows x 2 columns]
#                 ECOQ3  ECOQ3_encoded
# ...

# %%
df['ECOQ3_encoded'].head(10)
# Out:
# 0    NaN
# 1    NaN
# 2    4.0
# 3    3.0
# 4    1.0
# 5    4.0
# 6    4.0
# 7    3.0
# 8    4.0
# 9    NaN
# Name: ECOQ3_encoded, dtype: float64

# %%
null_counts = df.isnull().sum()

null_counts = null_counts[null_counts > 0]


plt.figure(figsize=(10, 6))
null_counts.plot(kind='bar', color='coral')
plt.title('Null Values per Column', fontsize=16, fontweight='bold')
plt.xlabel('Columns', fontsize=12)
plt.ylabel('Number of Null Values', fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', alpha=0.3)
plt.show()

# Print summary
print(f"Total null values: {null_counts.sum()}")
print(f"Columns with nulls: {len(null_counts)}")
# Out:
# Total null values: 30
# Columns with nulls: 1

# %%
df['ECOQ3_encoded'].fillna(df['ECOQ3_encoded'].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-2368280122.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['ECOQ3_encoded'].fillna(df['ECOQ3_encoded'].mode()[0], inplace=True)

# %%
print("number of null value is: ",df['ECOQ3_encoded'].isnull().sum())
# Out:
# number of null value is:  0

# %%
fin1_map = {
    'Extra money paid on borrowed money': 1,
    'A type of tax': 0,
    'Fee for mobile banking': 0,
    "I don't know": 0,

}

df['FINQ1_encoded'] = df['FINQ1'].map(fin1_map)
print(df[['FINQ1', 'FINQ1_encoded']])

fin2_map = {
    'Increase in prices over time': 1,
    'Decrease in income': 0,
    'Government savings plan': 0,
    "I don't know": 0,

}

df['FINQ2_encoded'] = df['FINQ2'].map(fin2_map)
print(df[['FINQ2', 'FINQ2_encoded']])

fin3_map = {
    'A financial plan for expenses and income': 1,
    'A type of loan': 0,
    'A bank account': 0,
    "I don't know": 0,

}

df['FINQ3_encoded'] = df['FINQ3'].map(fin3_map)
print(df[['FINQ3', 'FINQ3_encoded']])


fin4_map = {
    'A bank account to save money': 1,
    'A loan account': 0,
    'Only for mobile banking': 0,
    "I don't know": 0,

}

df['FINQ4_encoded'] = df['FINQ4'].map(fin4_map)
print(df[['FINQ4', 'FINQ4_encoded']])

fin5_map = {
    'Banking using a mobile phone': 1,
    'Paying utility bills only': 0,
    'Using ATM services': 0,
    "I don't know": 0,

}

df['FINQ5_encoded'] = df['FINQ5'].map(fin5_map)
print(df[['FINQ5', 'FINQ5_encoded']])

fin6_map = {
    'Debit uses your own money; credit is borrowed money': 1,
    'Both are the same': 0,
    'Debit is only for online use': 0,
    "I don't know": 0,

}

df['FINQ6_encoded'] = df['FINQ6'].map(fin6_map)
print(df[['FINQ6', 'FINQ6_encoded']])

fin7_map = {
    'Higher risk = higher potential return': 1,
    'Higher risk = lower return': 0,
    'No relationship': 0,
    "I don't know": 0,

}

df['FINQ7_encoded'] = df['FINQ7'].map(fin7_map)
print(df[['FINQ7', 'FINQ7_encoded']])

fin8_map = {
    'Financial protection against unexpected loss': 1,
    'A savings account type': 0,
    'A loan service': 0,
    "I don't know": 0,

}

df['FINQ8_encoded'] = df['FINQ8'].map(fin8_map)
print(df[['FINQ8', 'FINQ8_encoded']])
# Out:
#                                  FINQ1  FINQ1_encoded
# 0                         I don't know              0
# 1   Extra money paid on borrowed money              1
# 2   Extra money paid on borrowed money              1
# 3   Extra money paid on borrowed money              1
# 4   Extra money paid on borrowed money              1
# ..                                 ...            ...
# 79  Extra money paid on borrowed money              1
# 80  Extra money paid on borrowed money              1
# 81  Extra money paid on borrowed money              1
# 82  Extra money paid on borrowed money              1
# 83  Extra money paid on borrowed money              1
#
# [84 rows x 2 columns]
#                            FINQ2  FINQ2_encoded
# 0   Increase in prices over time              1
# 1   Increase in prices over time              1
# 2   Increase in prices over time              1
# 3   Increase in prices over time              1
# 4   Increase in prices over time              1
# ...

# %%
eco_answers = df['ECOQ1_encoded'] + df['ECOQ2_encoded'] +df['ECOQ3_encoded'] + df['ECOQ4_encoded'] + df['ECOQ5_encoded']
df['eco_answers'] = eco_answers
df['eco_answers'].head()
# Out:
# 0    18.0
# 1    15.0
# 2    17.0
# 3    15.0
# 4    14.0
# Name: eco_answers, dtype: float64

# %%
economic_empowerment_score = (eco_answers / 250) * 10
df['economic_empowerment_score'] = economic_empowerment_score
df['economic_empowerment_score'].head()
# Out:
# 0    0.72
# 1    0.60
# 2    0.68
# 3    0.60
# 4    0.56
# Name: economic_empowerment_score, dtype: float64

# %%
fin_answers = df['FINQ1_encoded'] + df['FINQ2_encoded'] +df['FINQ3_encoded'] + df['FINQ4_encoded'] + df['FINQ5_encoded'] + df['FINQ6_encoded'] + df['FINQ7_encoded'] + df['FINQ8_encoded']
df['fin_answers'] = fin_answers
df['fin_answers'].head()
# Out:
# 0    5
# 1    8
# 2    8
# 3    8
# 4    8
# Name: fin_answers, dtype: int64

# %%
financial_literacy_score = (fin_answers/8) * 10
df['financial_literacy_score'] = financial_literacy_score
df['financial_literacy_score'].head()
# Out:
# 0     6.25
# 1    10.00
# 2    10.00
# 3    10.00
# 4    10.00
# Name: financial_literacy_score, dtype: float64

# %%
df['Family Income (Monthly)'].value_counts()
# Out:
# Family Income (Monthly)
# Above 100,000       54
# 60,000 - 100,000    17
# 30,000 - 60,000      7
# Below 30,000         6
# Name: count, dtype: int64

# %%
income_map = {
    'Below 30,000': 20000,
    '30,000 - 60,000': 50000,
    '60,000 - 100,000': 80000,
    "Above 100,000": 110000,

}

df['income_encoded'] = df['Family Income (Monthly)'].map(income_map)
print(df[['Family Income (Monthly)', 'income_encoded']])
# Out:
#    Family Income (Monthly)  income_encoded
# 0         60,000 - 100,000           80000
# 1            Above 100,000          110000
# 2            Above 100,000          110000
# 3            Above 100,000          110000
# 4            Above 100,000          110000
# ..                     ...             ...
# 79           Above 100,000          110000
# 80           Above 100,000          110000
# 81        60,000 - 100,000           80000
# 82           Above 100,000          110000
# 83            Below 30,000           20000
#
# [84 rows x 2 columns]

# %% [markdown]
# # Data Visualization
#
# Descriptive statistics -> avg values of each score and income as a horizontal bar chart
#
# 1.mean income
#
# 2.literacy score average
#
# 3.empowerment score average
#
# _______
#
# correlation analysis -> heatmap
#
# find relationship between:
#
# 1.education to financial literacy
#
# 2.family income to economic empowerment
#
# 3.financial literacy to economic empowerment

# %%
income_averages = df.groupby('Family Income (Monthly)')['income_encoded'].mean().sort_values()
plt.figure(figsize=(10, 6))
plt.barh(class_averages.index, class_averages.values, color='coral', edgecolor='black')
plt.xlabel('Average income Score', fontsize=12)
plt.ylabel('Family Income (Monthly)', fontsize=12)
plt.title('Average Family Income (Monthly)', fontsize=14, fontweight='bold')
plt.grid(axis='x', alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 2.1:  Family Income Distribution                                      This graph shows subjects family income brackets. Most families fall in the middle-income range (30,000-100,000 PKR monthly), matching with our target demographic. The least represented groups are the highest and lowest income brackets, validating our focus on low to middle-income urban youth.

# %%
fin_counts = df['financial_literacy_score'].value_counts()
plt.figure(figsize=(8, 6))
fin_counts.plot(kind='bar')
plt.title('financial literacy average score')
plt.xlabel('financial_literacy_score')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 2.2: Financial Literacy Score Distribution
# This graph shows the pattern of financial literacy scores among subjects. Majority respondents scored in the medium range (4-6 out of 8), showing a basic understanding of financial concepts. The least number of subjects achieved either very high or very low scores, showing consistent average knowledge levels across the sample.

# %%
df["economic_empowerment_score"].value_counts()
df['economic_empowerment_score'] = df['economic_empowerment_score'].round(2)

# %%
eco_counts = df['economic_empowerment_score'].value_counts()
plt.figure(figsize=(8, 6))
eco_counts.plot(kind='bar')
plt.title('economic empowerment average score')
plt.xlabel('economic_empowerment_score')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Figure 2.3: Economic Empowerment Score Distribution
# This graph show how economic empowerment scores are arranged. Most subjects show average empowerment levels (6-7 out of 10), showing they feel partially in control of their financial decisions. The least common were extreme high or low empowerment scores, indicating generally parallel perceptions of economic agency.

# %%
df["Parents' Education"].value_counts()
# Out:
# Parents' Education
# Bachelor’s             31
# Master’s or above      24
# Secondary              20
# Primary                 6
# No formal education     3
# Name: count, dtype: int64

# %%
edu_map = {
    'Master’s or above': 5,
    'Bachelor’s': 4,
    'Secondary': 3,
    'Primary': 2,
    'No formal education':1

}

df['education_encoded'] = df["Parents' Education"].map(edu_map)
print(df[["Parents' Education", 'education_encoded']])
# Out:
#      Parents' Education  education_encoded
# 0             Secondary                  3
# 1            Bachelor’s                  4
# 2     Master’s or above                  5
# 3            Bachelor’s                  4
# 4     Master’s or above                  5
# ..                  ...                ...
# 79    Master’s or above                  5
# 80    Master’s or above                  5
# 81           Bachelor’s                  4
# 82  No formal education                  1
# 83              Primary                  2
#
# [84 rows x 2 columns]

# %%
import seaborn as sns
selected_columns = ['income_encoded','education_encoded', 'financial_literacy_score', 'economic_empowerment_score']
df_subset = df[selected_columns]
correlation = df[['income_encoded','education_encoded', 'financial_literacy_score', 'economic_empowerment_score']].corr()
sns.heatmap(correlation, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Correlation Analysis
#
# Figure 2.4: Correlation Heatmap of Key Variables
# The heatmap show relationships among financial literacy score, income, education, and economic empowerment.
#
# Education & Financial Literacy: Positive correlation (0.45) higher education lead to better financial knowledge
#
# Income & Economic Empowerment: Weak positive correlation (0.081) family income feel slightly influences empowerment
#
# Financial Literacy & Economic Empowerment: Very weak positive correlation (0.014) financial knowledge alone has very small impact on empowerment.
# Note: These correlations explained because because to the limited sample size and potential sampling bias
